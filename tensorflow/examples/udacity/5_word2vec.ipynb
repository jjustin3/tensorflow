# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.051575
# Nearest to such: erect, candlemas, chitin, chemist, genitals, xry, cows, overhauled,
# Nearest to after: gilded, chemotherapeutic, ethertype, porcelain, waldo, manhattan, nunnery, rebound,
# Nearest to most: gbu, lupin, intensify, rider, chapels, disloyal, ng, anymore,
# Nearest to so: typology, hartford, partnership, proportionality, droughts, wollheim, tk, coat,
# Nearest to that: herbrand, fairgrounds, interchange, troglodytes, seaborg, sarajevo, increased, procedure,
# Nearest to a: klan, lg, freising, pharmacies, begged, splines, tsunamis, exiles,
# Nearest to system: alexei, jewishencyclopedia, eug, aldrich, militias, bantam, kampf, nokia,
# Nearest to than: thereby, oi, feathered, wulf, suited, rica, orthographic, sidewinder,
# Nearest to as: expectancies, zealots, became, sisters, guitarists, backwaters, bebop, mockumentary,
# Nearest to united: jit, sugar, bunch, infanta, enroll, biloxi, glaring, knew,
# Nearest to on: waived, professionally, graduates, unequivocally, game, propel, telecommunication, review,
# Nearest to years: today, muller, vogt, virginal, wingers, chopping, moto, idiosyncratic,
# Nearest to be: contends, icebergs, snatch, pup, laboratories, closed, darussalam, guilds,
# Nearest to during: word, mannheim, lovely, naguib, macrocosm, jeffery, mcgowan, waved,
# Nearest to also: cartographer, raptor, capsules, tolerated, irish, positively, nader, agesilaus,
# Nearest to time: mixolydian, lions, murky, sanskaras, yearning, timing, visionaries, sculpting,
# Average loss at step 2000: 4.366637
# Average loss at step 4000: 3.869355
# Average loss at step 6000: 3.782532
# Average loss at step 8000: 3.691867
# Average loss at step 10000: 3.613556
# Nearest to such: annihilate, many, include, overhauled, well, gallant, instantiation, benford,
# Nearest to after: essays, geographically, ethertype, in, bray, rowing, banned, smoothing,
# Nearest to most: reissued, disloyal, intensify, word, lattices, phrasing, sociable, betrayed,
# Nearest to so: hartford, autistic, patrilineal, caldera, partnership, tk, woodcut, multicast,
# Nearest to that: which, continues, polytechnical, mannerheim, rooney, sleepless, it, when,
# Nearest to a: the, its, arboreal, this, defined, no, schelling, colloids,
# Nearest to system: jewishencyclopedia, alexei, aldrich, bantam, nokia, pinpoint, gentle, australian,
# Nearest to than: ibadi, thereby, sprengel, or, male, wulf, suited, orthographic,
# Nearest to as: auroral, panama, verona, in, hakim, by, became, expectancies,
# Nearest to united: sugar, jit, geopolitical, mikael, subsequent, fam, bunch, fatou,
# Nearest to on: in, at, with, recapitulation, propel, slashed, deteriorating, and,
# Nearest to years: today, muller, thunderbolt, halide, corning, chopping, vogt, fecal,
# Nearest to be: have, produce, become, was, filmi, by, caa, is,
# Nearest to during: word, programming, varieties, in, murders, maslow, mabuse, ju,
# Nearest to also: still, icftu, there, not, fontainebleau, wanna, often, which,
# Nearest to time: barreled, sanskaras, hinterlands, glassware, bakersfield, housing, aeneas, banda,
# Average loss at step 12000: 3.604353
# Average loss at step 14000: 3.568871
# Average loss at step 16000: 3.407522
# Average loss at step 18000: 3.458322
# Average loss at step 20000: 3.538083
# Nearest to such: these, well, many, instantiation, dualist, overhauled, include, annihilate,
# Nearest to after: before, from, when, martov, bray, essays, rowing, mitochondrial,
# Nearest to most: more, some, many, reissued, disloyal, dollar, rosemary, phrasing,
# Nearest to so: patrilineal, hartford, autistic, partnership, tk, certainly, droughts, proportionality,
# Nearest to that: which, when, this, but, what, increased, collisions, continues,
# Nearest to a: the, this, freising, defined, or, disappearance, favorably, coquitlam,
# Nearest to system: jewishencyclopedia, bantam, alexei, aldrich, nokia, irregularities, game, constant,
# Nearest to than: or, sprengel, male, orthographic, suited, ibadi, thereby, wulf,
# Nearest to as: absurdist, digitization, intelligencer, spinach, prophesy, universal, logical, cartilage,
# Nearest to united: geopolitical, jit, sugar, mikael, subsequent, bunch, entire, bends,
# Nearest to on: in, at, recapitulation, into, with, upon, propel, merseyside,
# Nearest to years: today, thunderbolt, muller, corning, halide, vanir, idiosyncratic, chopping,
# Nearest to be: been, produce, have, is, was, by, were, make,
# Nearest to during: first, among, in, word, pelletier, grieg, while, after,
# Nearest to also: now, which, inseparable, still, icftu, not, chekhov, often,
# Nearest to time: barreled, course, year, sanskaras, surprising, capillary, nagasaki, hinterlands,
# Average loss at step 22000: 3.505940
# Average loss at step 24000: 3.492109
# Average loss at step 26000: 3.480902
# Average loss at step 28000: 3.480398
# Average loss at step 30000: 3.507805
# Nearest to such: well, these, instantiation, include, many, known, antiaircraft, benford,
# Nearest to after: before, when, during, from, for, martov, pasquale, rowing,
# Nearest to most: more, many, some, reissued, disloyal, among, chicks, compounded,
# Nearest to so: patrilineal, hartford, autistic, certainly, laconia, hieronymus, caldera, partnership,
# Nearest to that: which, what, this, how, where, increased, when, analogous,
# Nearest to a: schelling, any, the, no, satisfiable, another, stipulate, choctaws,
# Nearest to system: jewishencyclopedia, alexei, nokia, bantam, systems, aldrich, fordham, smithsonian,
# Nearest to than: sprengel, orthographic, much, male, or, wulf, vitoria, ibadi,
# Nearest to as: nikos, fuhito, when, spinach, by, starving, devito, with,
# Nearest to united: geopolitical, jit, mikael, bends, entire, subsequent, sugar, bunch,
# Nearest to on: upon, in, from, into, through, during, at, between,
# Nearest to years: days, today, decades, muller, corning, months, people, halide,
# Nearest to be: been, have, produce, is, was, are, were, make,
# Nearest to during: in, after, on, when, before, since, neurotic, first,
# Nearest to also: now, often, still, sometimes, which, who, it, employed,
# Nearest to time: barreled, year, sanskaras, course, capillary, hoffa, nationale, algorithm,
# Average loss at step 32000: 3.498770
# Average loss at step 34000: 3.494746
# Average loss at step 36000: 3.457062
# Average loss at step 38000: 3.300768
# Average loss at step 40000: 3.426786
# Nearest to such: well, these, known, including, instantiation, certain, other, include,
# Nearest to after: before, when, during, while, martov, for, rowing, had,
# Nearest to most: more, many, reissued, among, some, concatenation, phrasing, nzwani,
# Nearest to so: patrilineal, hartford, autistic, certainly, ragga, too, canary, ducas,
# Nearest to that: which, this, what, however, where, it, sleepless, when,
# Nearest to a: the, another, or, any, penetrative, satisfiable, efficiencies, buena,
# Nearest to system: systems, jewishencyclopedia, nokia, islets, fordham, bantam, core, smithsonian,
# Nearest to than: or, sprengel, much, orthographic, trough, wulf, ear, literatures,
# Nearest to as: consolidated, when, bamberger, bukharin, devito, murad, digitization, spinach,
# Nearest to united: geopolitical, bends, jit, ennio, mikael, whim, bunch, fam,
# Nearest to on: upon, at, during, with, through, professionally, against, before,
# Nearest to years: days, decades, months, weeks, muller, centuries, corning, halide,
# Nearest to be: have, been, is, was, produce, perk, are, by,
# Nearest to during: in, after, at, on, since, when, before, against,
# Nearest to also: still, which, often, now, sometimes, commonly, kramnik, who,
# Nearest to time: year, course, day, lendl, hoffa, period, surprising, algorithm,
# Average loss at step 42000: 3.432240
# Average loss at step 44000: 3.451846
# Average loss at step 46000: 3.451820
# Average loss at step 48000: 3.352434
# Average loss at step 50000: 3.382594
# Nearest to such: these, well, known, instantiation, many, kilmister, certain, including,
# Nearest to after: before, when, during, while, though, andrei, from, for,
# Nearest to most: more, many, some, less, among, nzwani, reissued, sheik,
# Nearest to so: too, hartford, ragga, autistic, patrilineal, certainly, excuses, kilmister,
# Nearest to that: which, however, what, where, helene, but, this, polytechnical,
# Nearest to a: any, another, schelling, the, disgusted, choctaws, wretched, filial,
# Nearest to system: systems, jewishencyclopedia, nokia, islets, smithsonian, kettle, bantam, regrouped,
# Nearest to than: or, ear, sprengel, much, orthographic, auroral, literatures, crass,
# Nearest to as: became, digitization, carries, panama, cartilage, by, manly, when,
# Nearest to united: geopolitical, bends, whim, bunch, jit, ennio, mikael, comers,
# Nearest to on: upon, recapitulation, through, in, into, at, jock, from,
# Nearest to years: days, decades, months, weeks, times, year, centuries, tons,
# Nearest to be: have, been, become, is, are, was, londoners, were,
# Nearest to during: in, after, when, while, since, from, strictest, through,
# Nearest to also: still, which, now, sometimes, often, who, subsequently, middletown,
# Nearest to time: year, way, lendl, period, day, course, if, cataract,
# Average loss at step 52000: 3.435957
# Average loss at step 54000: 3.430916
# Average loss at step 56000: 3.437776
# Average loss at step 58000: 3.396209
# Average loss at step 60000: 3.399357
# Nearest to such: these, known, many, including, certain, well, instantiation, kilmister,
# Nearest to after: before, when, during, while, despite, though, although, throughout,
# Nearest to most: more, many, some, less, among, use, nzwani, thoroughfare,
# Nearest to so: too, hartford, certainly, autistic, if, patrilineal, ragga, subcultural,
# Nearest to that: which, however, what, this, it, there, often, also,
# Nearest to a: the, any, another, every, disgusted, colloids, this, hideo,
# Nearest to system: systems, game, nokia, aldrich, core, smithsonian, amyl, islets,
# Nearest to than: much, or, ear, aspect, logistical, sprengel, but, literatures,
# Nearest to as: digitization, spinach, consolidated, regained, became, herein, murad, emergent,
# Nearest to united: geopolitical, bends, whim, ennio, bunch, mikael, jit, shanghai,
# Nearest to on: upon, through, recapitulation, waived, amar, ideographic, in, wig,
# Nearest to years: days, decades, weeks, months, times, centuries, year, minutes,
# Nearest to be: been, is, become, was, have, create, perk, are,
# Nearest to during: after, in, although, before, since, including, despite, when,
# Nearest to also: now, still, often, sometimes, always, generally, which, who,
# Nearest to time: year, period, way, day, course, skid, feininger, selma,
# Average loss at step 62000: 3.240122
# Average loss at step 64000: 3.254274
# Average loss at step 66000: 3.397884
# Average loss at step 68000: 3.394294
# Average loss at step 70000: 3.359011
# Nearest to such: these, certain, known, including, well, some, many, kilmister,
# Nearest to after: before, during, when, despite, while, szl, though, if,
# Nearest to most: more, many, less, some, thoroughfare, use, coupled, among,
# Nearest to so: too, ragga, certainly, autistic, if, hartford, sometimes, calcutta,
# Nearest to that: which, however, what, this, but, where, usually, generally,
# Nearest to a: the, another, scavullo, any, enough, schelling, freising, gabrielle,
# Nearest to system: systems, nokia, amyl, akita, network, ladefoged, aldrich, islets,
# Nearest to than: or, but, literatures, ear, logistical, facilitation, and, scarlet,
# Nearest to as: helga, like, digitization, consolidated, is, erythrocytes, gerald, spinach,
# Nearest to united: geopolitical, bends, ennio, whim, fam, census, jit, megali,
# Nearest to on: upon, through, in, at, spontaneously, under, recapitulation, about,
# Nearest to years: days, decades, months, weeks, centuries, times, tons, minutes,
# Nearest to be: been, become, is, were, easily, have, was, produce,
# Nearest to during: after, before, in, until, despite, although, while, through,
# Nearest to also: now, still, often, sometimes, never, which, generally, usually,
# Nearest to time: year, if, skid, way, hoffa, feininger, selma, place,
# Average loss at step 72000: 3.380395
# Average loss at step 74000: 3.347265
# Average loss at step 76000: 3.317805
# Average loss at step 78000: 3.356958
# Average loss at step 80000: 3.375587
# Nearest to such: these, known, well, certain, including, kilmister, follows, torre,
# Nearest to after: before, during, when, despite, while, though, martov, without,
# Nearest to most: many, some, less, more, thoroughfare, among, sheik, disloyal,
# Nearest to so: too, ragga, binocular, how, if, certainly, catches, excuses,
# Nearest to that: which, however, what, where, lava, sleepless, bald, then,
# Nearest to a: another, schelling, disgusted, every, the, scavullo, venerated, meritocratic,
# Nearest to system: systems, aldrich, akita, nokia, network, smithsonian, kittiwake, misheard,
# Nearest to than: ear, much, but, while, or, crass, facilitation, even,
# Nearest to as: corridor, digitization, carries, when, cartilage, taboo, quotas, numerical,
# Nearest to united: geopolitical, bends, ennio, phoenicia, whim, census, fam, condemns,
# Nearest to on: upon, in, through, recapitulation, under, off, ptah, expanse,
# Nearest to years: days, decades, months, weeks, centuries, times, minutes, year,
# Nearest to be: been, become, have, being, perk, produce, provide, easily,
# Nearest to during: after, in, when, despite, before, until, although, through,
# Nearest to also: now, still, sometimes, often, never, which, middletown, aurochs,
# Nearest to time: year, lendl, skid, wishful, stealing, harness, thing, century,
# Average loss at step 82000: 3.403243
# Average loss at step 84000: 3.409610
# Average loss at step 86000: 3.390146
# Average loss at step 88000: 3.352059
# Average loss at step 90000: 3.362805
# Nearest to such: known, well, these, including, certain, follows, described, many,
# Nearest to after: before, when, during, despite, while, until, if, though,
# Nearest to most: less, some, many, more, use, thoroughfare, among, nzwani,
# Nearest to so: too, if, ragga, binocular, autistic, geiger, excuses, thus,
# Nearest to that: which, however, what, disciple, but, generally, instead, clearly,
# Nearest to a: another, any, buena, disgusted, satisfiable, the, stipulate, scavullo,
# Nearest to system: systems, smithsonian, network, aldrich, akita, amyl, nokia, distinction,
# Nearest to than: ear, much, studs, aspect, no, martina, facilitation, literatures,
# Nearest to as: majorca, postwar, digitization, numerical, devito, authorizes, spinach, sutcliffe,
# Nearest to united: geopolitical, bends, ennio, phoenicia, whim, minoan, megali, supreme,
# Nearest to on: upon, under, through, in, at, scoping, towards, spontaneously,
# Nearest to years: days, decades, months, weeks, minutes, centuries, times, hours,
# Nearest to be: been, provide, become, is, have, was, being, perk,
# Nearest to during: after, in, before, when, although, despite, while, through,
# Nearest to also: still, often, now, sometimes, which, generally, actually, colt,
# Nearest to time: year, skid, period, feininger, day, if, stealing, hypothesis,
# Average loss at step 92000: 3.398024
# Average loss at step 94000: 3.252341
# Average loss at step 96000: 3.361454
# Average loss at step 98000: 3.241001
# Average loss at step 100000: 3.357864
# Nearest to such: known, well, including, certain, follows, these, many, described,
# Nearest to after: before, during, when, despite, until, without, since, though,
# Nearest to most: less, more, some, use, among, nzwani, thoroughfare, sheik,
# Nearest to so: too, thus, if, binocular, ragga, excuses, autistic, geiger,
# Nearest to that: which, however, what, helene, disciple, this, who, where,
# Nearest to a: another, the, enough, any, disgusted, colloids, buena, potos,
# Nearest to system: systems, misheard, akita, smithsonian, hydrogenation, syndromes, network, function,
# Nearest to than: or, much, ear, literatures, facilitation, even, aspect, ibadi,
# Nearest to as: helga, devito, majorca, when, spinach, fuhito, cartilage, became,
# Nearest to united: geopolitical, bends, ennio, whim, rest, minoan, census, phoenicia,
# Nearest to on: upon, in, at, through, near, under, against, doris,
# Nearest to years: days, decades, months, weeks, centuries, minutes, year, hours,
# Nearest to be: been, is, become, being, have, are, filmi, eiga,
# Nearest to during: after, in, when, despite, throughout, before, until, since,
# Nearest to also: now, still, sometimes, often, actually, never, generally, usually,
# Nearest to time: year, thing, feininger, place, hypothesis, skid, way, lendl,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Generation
def generate_batch(batch_size, skip_window):
    global data_index
 
    span = 2 * skip_window + 1
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
 
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
         
        # This part new - we are generating a batch of tuples, so need to add avoid word for next go-around
        # i.e. for 'I ran super fast yesterday'
        # batch: [ ['I', 'super'], ['ran', 'fast'], ['super', 'yesterday'] ]
        # labels: ['ran', 'super', 'fast']
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            batch[i,col_idx] = buffer[j]
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()


### Procedure
# Look at each column in train_dataset (size: b x 2 * skip_window)
# Lookup embeddings for word IDs in the column
# Save embeddings to temp var (embeddings_i)
# Concat all embeddings in embeddings_i to create new compound var (embeds, size: 2 * skip_window x b x D)
# Perform reduce mean on axis 0
# => avg embeddings of corresponding contextual words of words in train_labels for each batch of data

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    # this is new -> span - 1 = 2 * skip_window
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    # embedding, vector for each word in the vocabulary
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Averaging embeddings accross the full context into a single embedding layer
    # this is new -> span - 1 = 2 * skip_window
    context_embeddings = []
    for i in range(2*skip_window):
        context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))

    avg_embed = tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)    

    # Compute the softmax loss, using a sample of the negative labels each time.
    # inputs are embeddings of the train words
    # with this loss we optimize weights, biases, embeddings
    
    # this is new - use avg_embed instead of single embedding
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                           labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.203580
# Nearest to were: ethernet, populate, classifies, saragossa, endorse, bergson, minos, republica,
# Nearest to to: changeable, infinite, figurative, frame, mysql, lambs, vacuole, forth,
# Nearest to than: tennessee, herrera, mild, mt, m, nfs, justifies, banks,
# Nearest to two: refurbished, macho, beltane, bowels, sardinia, ruthenian, koenigsegg, saint,
# Nearest to not: bioses, moro, weavers, qualifications, evenings, shafts, decried, rcs,
# Nearest to however: quiet, counterfeiting, interquartile, road, varnish, solves, wavelengths, resorting,
# Nearest to so: open, enrichment, spinoffs, civitas, rhino, characterise, tchaikovsky, chianti,
# Nearest to world: denver, dachau, intermarriage, cranial, adepts, terrence, rita, realism,
# Nearest to most: tradesmen, vienna, ammonite, remarked, freedom, fawn, elmer, hine,
# Nearest to known: ocaml, wiesbaden, mengele, tyrants, vigilance, polanyi, tracts, mantis,
# Nearest to zero: chooses, doubleheader, benedictine, mohawk, burgundian, gallbladder, afield, microbe,
# Nearest to its: ci, gl, melville, ioi, mapuche, desmo, much, descent,
# Nearest to it: metonic, molinari, populations, helaman, noll, soy, spoiler, endorse,
# Nearest to when: ottonian, salam, spectacles, autocephalous, waving, lineup, juvenal, hittites,
# Nearest to called: triphosphate, gasolines, health, spurred, lok, htm, optically, radon,
# Nearest to for: sense, rockers, multiplexing, loves, trying, fortified, oblast, tomb,
# Average loss at step 2000: 4.006990
# Average loss at step 4000: 3.399065
# Average loss at step 6000: 3.312597
# Average loss at step 8000: 3.284422
# Average loss at step 10000: 3.217456
# Nearest to were: are, was, airports, have, calvinist, be, bovine, ethernet,
# Nearest to to: changeable, frame, can, lambs, genocides, distributions, figurative, oldest,
# Nearest to than: justifies, nfs, rufinus, tennessee, mondeo, limbs, infield, peking,
# Nearest to two: four, three, eight, six, one, seven, five, nine,
# Nearest to not: never, they, also, usually, broth, rbi, reprisal, will,
# Nearest to however: solves, appalachia, although, sirens, berserker, when, masons, became,
# Nearest to so: open, ballparks, arousal, cse, andersen, evident, clowning, misunderstood,
# Nearest to world: dachau, cranial, intermarriage, early, denver, nudes, retrofitted, marriage,
# Nearest to most: crespigny, tradesmen, remarked, rationale, humanitarians, luc, ifr, lynyrd,
# Nearest to known: well, used, polanyi, lumumba, such, publicise, ridicule, amusingly,
# Nearest to zero: five, six, eight, four, nine, seven, three, two,
# Nearest to its: their, the, her, his, some, lasi, suppression, millsaps,
# Nearest to it: he, there, still, metonic, she, varnothing, vance, they,
# Nearest to when: if, where, gy, seleucus, frederic, after, yielded, pyruvate,
# Nearest to called: eliminating, herald, freeform, arabians, triphosphate, mileage, gerais, dieting,
# Nearest to for: under, during, sybil, noel, from, peppard, bathtub, oblast,
# Average loss at step 12000: 3.221595
# Average loss at step 14000: 3.186219
# Average loss at step 16000: 3.047796
# Average loss at step 18000: 3.106812
# Average loss at step 20000: 3.060908
# Nearest to were: are, was, have, had, be, been, calvinist, is,
# Nearest to to: changeable, frame, would, cannot, will, lambs, vacuole, oldest,
# Nearest to than: justifies, nfs, rufinus, recently, backwardness, peking, limbs, or,
# Nearest to two: three, four, six, five, one, seven, eight, herrera,
# Nearest to not: never, usually, they, also, still, rbi, always, georges,
# Nearest to however: although, but, though, solves, sirens, that, zeitung, berserker,
# Nearest to so: evident, ballparks, open, andersen, arousal, clowning, cameras, really,
# Nearest to world: cranial, dachau, repeat, denver, contest, insuring, marvellous, uk,
# Nearest to most: crespigny, ifr, rationale, more, agates, tradesmen, knuckles, fosters,
# Nearest to known: used, regarded, well, such, publicise, amusingly, available, hexagon,
# Nearest to zero: eight, six, seven, five, four, nine, three, benedictine,
# Nearest to its: their, her, his, the, banshee, reserves, suppression, empedocles,
# Nearest to it: he, she, there, this, still, ninja, they, miner,
# Nearest to when: if, where, seleucus, after, yielded, before, frederic, lineup,
# Nearest to called: htm, baudot, compendium, eliminating, ultimate, arabians, mileage, named,
# Nearest to for: during, against, under, peppard, mercer, noel, pump, propagandist,
# Average loss at step 22000: 3.035517
# Average loss at step 24000: 3.049284
# Average loss at step 26000: 3.032840
# Average loss at step 28000: 2.851503
# Average loss at step 30000: 2.997967
# Nearest to were: are, was, have, been, be, had, calvinist, minden,
# Nearest to to: cannot, changeable, lambs, might, would, could, not, must,
# Nearest to than: justifies, nfs, bs, or, rufinus, peking, backwardness, recently,
# Nearest to two: three, four, six, five, eight, seven, nine, one,
# Nearest to not: never, usually, always, still, to, increasingly, they, exhibit,
# Nearest to however: but, although, that, though, metropolises, sirens, saw, lana,
# Nearest to so: ballparks, clowning, evident, andersen, arousal, resh, tchaikovsky, abatis,
# Nearest to world: cranial, litigated, pseudonym, repeat, uk, ungodly, flaw, contest,
# Nearest to most: more, rationale, ifr, adc, some, dylan, crespigny, msi,
# Nearest to known: used, regarded, available, described, defined, well, publicise, such,
# Nearest to zero: eight, five, six, nine, seven, four, three, two,
# Nearest to its: their, her, his, the, suppression, banshee, reserves, diminish,
# Nearest to it: he, there, she, this, they, ninja, still, which,
# Nearest to when: if, where, after, before, while, against, seleucus, yielded,
# Nearest to called: ultimate, compendium, baudot, named, htm, abolishes, arabians, streetcar,
# Nearest to for: against, peppard, without, ise, daunting, mercer, sybil, cytoplasmic,
# Average loss at step 32000: 2.982704
# Average loss at step 34000: 2.971196
# Average loss at step 36000: 2.923311
# Average loss at step 38000: 2.981874
# Average loss at step 40000: 2.956320
# Nearest to were: are, have, was, had, be, been, wadis, aligning,
# Nearest to to: cannot, changeable, will, oldest, must, mandrakesoft, would, lambs,
# Nearest to than: or, rufinus, justifies, sexism, backwardness, nfs, bs, mauritania,
# Nearest to two: three, four, five, six, seven, one, eight, herrera,
# Nearest to not: never, usually, always, still, increasingly, probably, now, generally,
# Nearest to however: although, but, that, though, while, throughout, ural, saw,
# Nearest to so: clowning, ballparks, arousal, how, resh, andersen, tchaikovsky, really,
# Nearest to world: repeat, topol, pseudonym, litigated, cranial, uk, judgments, flaw,
# Nearest to most: more, some, many, crespigny, ifr, less, adc, rationale,
# Nearest to known: used, regarded, defined, described, available, opposed, classified, such,
# Nearest to zero: eight, five, seven, six, four, nine, three, million,
# Nearest to its: their, his, her, the, banshee, empedocles, diminish, reserves,
# Nearest to it: he, she, there, this, they, ninja, often, varnothing,
# Nearest to when: if, after, before, where, while, seleucus, within, frederic,
# Nearest to called: named, baudot, considered, htm, amelia, abolishes, ultimate, arabians,
# Nearest to for: peppard, against, pump, appleby, during, hsuan, without, sybil,
# Average loss at step 42000: 2.931264
# Average loss at step 44000: 2.889251
# Average loss at step 46000: 2.854758
# Average loss at step 48000: 2.909283
# Average loss at step 50000: 2.881180
# Nearest to were: are, have, had, was, been, be, wadis, simpson,
# Nearest to to: changeable, cannot, lambs, mandrakesoft, would, hauled, will, oldest,
# Nearest to than: or, rufinus, sexism, bs, justifies, peking, backwardness, recently,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to not: never, always, still, usually, increasingly, kabila, now, probably,
# Nearest to however: but, although, that, though, while, throughout, there, motivation,
# Nearest to so: clowning, arousal, how, really, ballparks, cameras, resh, evident,
# Nearest to world: repeat, litigated, topol, flaw, judgments, pseudonym, uk, cranial,
# Nearest to most: more, some, many, less, crespigny, especially, highly, fugazi,
# Nearest to known: used, defined, regarded, described, opposed, available, such, classified,
# Nearest to zero: five, seven, four, eight, six, nine, three, million,
# Nearest to its: their, his, her, the, empedocles, banshee, diminish, your,
# Nearest to it: he, she, there, this, they, ibizan, eventually, often,
# Nearest to when: if, after, while, before, where, although, during, within,
# Nearest to called: named, fence, considered, arabians, ultimate, baudot, amelia, htm,
# Nearest to for: during, engineered, without, peppard, boson, appleby, structural, against,
# Average loss at step 52000: 2.843749
# Average loss at step 54000: 2.804400
# Average loss at step 56000: 2.846457
# Average loss at step 58000: 2.853929
# Average loss at step 60000: 2.781786
# Nearest to were: are, was, have, had, be, been, evolves, wadis,
# Nearest to to: changeable, lambs, oldest, cannot, proclus, rnir, would, vacuole,
# Nearest to than: sexism, rinnan, backwardness, timer, or, rufinus, peking, asin,
# Nearest to two: three, four, five, six, seven, eight, one, thirty,
# Nearest to not: never, always, usually, still, increasingly, now, kabila, actually,
# Nearest to however: but, although, that, though, while, franchising, metropolises, and,
# Nearest to so: how, clowning, too, thus, arousal, ballparks, evident, really,
# Nearest to world: repeat, pseudonym, litigated, flaw, league, judgments, cranial, uk,
# Nearest to most: more, some, many, less, fugazi, rationale, crespigny, especially,
# Nearest to known: used, defined, regarded, opposed, described, available, classified, mentioned,
# Nearest to zero: eight, five, seven, four, six, nine, three, million,
# Nearest to its: their, his, her, the, banshee, your, our, empedocles,
# Nearest to it: he, she, there, this, they, tribunal, ibizan, itself,
# Nearest to when: if, after, while, before, where, although, during, until,
# Nearest to called: named, considered, used, referred, arabians, fence, ultimate, amelia,
# Nearest to for: against, appleby, cartilage, without, chk, when, peppard, during,
# Average loss at step 62000: 2.790709
# Average loss at step 64000: 2.745001
# Average loss at step 66000: 2.773308
# Average loss at step 68000: 2.808289
# Average loss at step 70000: 2.674803
# Nearest to were: are, have, was, had, been, be, those, evolves,
# Nearest to to: cannot, changeable, lambs, would, hauled, towards, will, oldest,
# Nearest to than: or, sexism, peking, rinnan, timer, asin, rufinus, backwardness,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to not: never, always, usually, actively, now, still, nearly, probably,
# Nearest to however: but, although, though, that, while, throughout, lana, despite,
# Nearest to so: how, thus, too, clowning, arousal, octavian, evident, really,
# Nearest to world: repeat, judgments, pseudonym, flaw, litigated, topol, ungodly, uk,
# Nearest to most: more, many, some, less, msi, highly, crespigny, manichaeism,
# Nearest to known: used, defined, regarded, opposed, described, available, mentioned, classified,
# Nearest to zero: eight, five, seven, six, four, nine, three, million,
# Nearest to its: their, his, her, the, banshee, your, our, diminish,
# Nearest to it: he, she, there, they, this, itself, ibizan, replicated,
# Nearest to when: if, after, before, while, where, although, during, until,
# Nearest to called: named, used, amelia, referred, considered, gesture, baudot, ultimate,
# Nearest to for: against, toward, during, ordinarily, alpacas, without, peppard, mercer,
# Average loss at step 72000: 2.819989
# Average loss at step 74000: 2.826302
# Average loss at step 76000: 2.783939
# Average loss at step 78000: 2.705812
# Average loss at step 80000: 2.770900
# Nearest to were: are, have, was, been, had, be, include, wadis,
# Nearest to to: changeable, cannot, would, towards, lambs, will, feldspar, dbms,
# Nearest to than: or, sexism, rufinus, rinnan, timer, peking, backwardness, asin,
# Nearest to two: three, four, five, six, seven, eight, nine, one,
# Nearest to not: never, always, actively, actually, now, otherwise, almost, really,
# Nearest to however: but, although, though, that, while, throughout, copperfield, cancelled,
# Nearest to so: how, too, somers, thus, evident, clowning, really, cameras,
# Nearest to world: repeat, judgments, olfactory, litigated, flaw, pseudonym, denver, smell,
# Nearest to most: more, many, some, less, especially, all, highly, rationale,
# Nearest to known: used, defined, regarded, opposed, described, mentioned, available, classified,
# Nearest to zero: five, eight, seven, six, four, nine, three, million,
# Nearest to its: their, his, her, the, your, banshee, whose, diminish,
# Nearest to it: he, she, this, there, they, itself, replicated, which,
# Nearest to when: if, while, after, before, where, although, platters, during,
# Nearest to called: named, referred, used, considered, amelia, arabians, ultimate, baudot,
# Nearest to for: without, while, after, against, unbiased, outstanding, har, ise,
# Average loss at step 82000: 2.753469
# Average loss at step 84000: 2.772285
# Average loss at step 86000: 2.745125
# Average loss at step 88000: 2.714620
# Average loss at step 90000: 2.733929
# Nearest to were: are, was, have, had, include, be, those, been,
# Nearest to to: changeable, must, cannot, would, might, mandrakesoft, lambs, towards,
# Nearest to than: or, sexism, timer, rufinus, much, rinnan, sinope, backwardness,
# Nearest to two: three, five, four, seven, six, eight, one, nine,
# Nearest to not: never, actively, always, actually, formally, otherwise, rarely, now,
# Nearest to however: but, although, though, that, throughout, while, martyrs, when,
# Nearest to so: how, too, thus, beyond, somers, cameras, evident, clowning,
# Nearest to world: repeat, judgments, litigated, olfactory, flaw, brandt, smell, prescott,
# Nearest to most: more, many, some, less, especially, highly, all, rationale,
# Nearest to known: used, defined, regarded, opposed, described, mentioned, available, possible,
# Nearest to zero: seven, five, eight, six, nine, four, three, two,
# Nearest to its: their, his, her, the, whose, your, empedocles, banshee,
# Nearest to it: he, she, there, they, this, itself, ibizan, replicated,
# Nearest to when: if, before, while, after, although, where, though, since,
# Nearest to called: named, referred, used, considered, baudot, known, primitivism, gesture,
# Nearest to for: without, oblast, appleby, propagandist, simplifies, ise, unbiased, mercer,
# Average loss at step 92000: 2.718856
# Average loss at step 94000: 2.348864
# Average loss at step 96000: 2.461520
# Average loss at step 98000: 2.615116
# Average loss at step 100000: 2.651541
# Nearest to were: are, have, was, had, include, be, wadis, been,
# Nearest to to: changeable, towards, cannot, lambs, would, must, hauled, could,
# Nearest to than: or, much, timer, rinnan, rufinus, sexism, sinope, ayn,
# Nearest to two: three, five, four, six, seven, eight, one, nine,
# Nearest to not: never, actively, always, formally, really, otherwise, actually, rarely,
# Nearest to however: but, although, though, that, while, copperfield, when, martyrs,
# Nearest to so: too, how, beyond, thus, tetrachloride, somers, mysterious, really,
# Nearest to world: judgments, repeat, olfactory, litigated, prescott, flaw, pseudonym, smell,
# Nearest to most: more, many, some, less, especially, highly, all, extremely,
# Nearest to known: regarded, defined, used, described, available, opposed, mentioned, possible,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to its: their, his, her, the, whose, banshee, your, our,
# Nearest to it: he, she, there, they, this, itself, replicated, ninja,
# Nearest to when: if, before, while, after, although, where, though, during,
# Nearest to called: named, referred, used, considered, artefacts, known, gesture, primitivism,
# Nearest to for: without, sole, appleby, against, platypus, after, swinburne, constabulary,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
